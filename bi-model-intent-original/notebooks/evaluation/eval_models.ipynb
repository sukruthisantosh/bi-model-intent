# %%
# !pip install bitsandbytes accelerate
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.8.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.34.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.1.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.8.3)
# Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 36.5 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.47.0

# %%
import json
import time
import torch
import pandas as pd
from typing import Dict, List, Any
from datetime import datetime
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
from huggingface_hub import login, HfApi
import warnings

warnings.filterwarnings("ignore", message="Caching is incompatible with gradient checkpointing")

# %%
# Model configurations
MODEL_CONFIGS = {
    "trained": {
        "base_model": "Qwen/Qwen2.5-1.5B-Instruct",
        "adapter_path": "ssuki/qwen-1.5b-entity-recognition",
        "name": "Trained Qwen 1.5B"
    },
    "untrained": {
        "base_model": "Qwen/Qwen2.5-1.5B-Instruct",
        "adapter_path": None,
        "name": "Untrained Qwen 1.5B"
    }
}

TEST_DATA_PATH = "./eval_examples_200-300.json"
PROMPT_PATH = "./entity_recognition_prompt.txt"

# %%
def load_test_data():
    """Load test examples."""
    with open(TEST_DATA_PATH, 'r', encoding='utf-8') as f:
        data = json.load(f)
    print(f"Loaded {len(data)} test examples")
    return data

def load_prompt_template():
    """Load the entity recognition prompt template."""
    with open(PROMPT_PATH, 'r', encoding='utf-8') as f:
        return f.read().strip()

def load_model_and_tokenizer(model_config: Dict[str, Any]):
    """Load model and tokenizer."""
    print(f"Loading {model_config['name']}...")

    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained(
        model_config['base_model'],
        trust_remote_code=True
    )
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.padding_side = "right"

    # Load base model
    model = AutoModelForCausalLM.from_pretrained(
        model_config['base_model'],
        torch_dtype=torch.float16,
        device_map="auto",
        trust_remote_code=True,
        quantization_config={
            "load_in_4bit": True,
            "bnb_4bit_compute_dtype": torch.float16,
            "bnb_4bit_use_double_quant": True,
            "bnb_4bit_quant_type": "nf4"
        }
    )

    # Load adapter if trained model
    if model_config['adapter_path']:
        try:
            model = PeftModel.from_pretrained(model, model_config['adapter_path'])
            print(f"Loaded adapter from {model_config['adapter_path']}")
        except Exception as e:
            print(f"Warning: Could not load adapter: {e}")
            print("Using base model instead")

    return model, tokenizer

# %%
def extract_correct_json(response_text):
    """Extract the correct JSON format from model response."""
    import json
    import re

    # Look for JSON in the response
    json_match = re.search(r'```json\s*(\[.*?\]|\{.*?\})\s*```', response_text, re.DOTALL)
    if json_match:
        json_str = json_match.group(1)
        try:
            parsed = json.loads(json_str)

            # If it's an array, take the first object and merge
            if isinstance(parsed, list) and len(parsed) > 0:
                # Merge all objects in the array
                merged = {
                    "dimensions": [],
                    "measures": [],
                    "calculations": [],
                    "filters": [],
                    "time_references": []
                }

                for item in parsed:
                    for key in merged:
                        if key in item:
                            merged[key].extend(item[key])

                return merged
            else:
                return parsed
        except:
            pass

    return None

def run_inference(model, tokenizer, test_data: List[Dict], model_name: str):
    """Run inference on test data and measure performance."""
    print(f"\nRunning inference with {model_name}...")

    prompt_template = load_prompt_template()
    results = []

    # Disable gradient checkpointing for faster inference
    model.gradient_checkpointing_disable()

    print(f"Starting inference on {len(test_data)} examples...")

    for i, example in enumerate(test_data):
        print(f"Processing example {i+1}/{len(test_data)}", end="\r")

        try:
            # Prepare input
            input_text = prompt_template.format(question=example['input'])
            print(f"\nInput text length: {len(input_text)}")

            inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=1024)
            print(f"Tokenized input shape: {inputs['input_ids'].shape}")

            # Move to device
            device = next(model.parameters()).device
            inputs = {k: v.to(device) for k, v in inputs.items()}
            print(f"Inputs moved to device: {device}")

            # Measure inference time
            start_time = time.time()
            print("Starting generation...")

            with torch.no_grad():
                outputs = model.generate(
                    **inputs,
                    max_new_tokens=256,
                    temperature=0.1,
                    do_sample=True,
                    pad_token_id=tokenizer.eos_token_id,
                    eos_token_id=tokenizer.eos_token_id,
                    use_cache=False
                )

            print("Generation completed!")
            inference_time = time.time() - start_time

            # Decode response
            generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

            # Find where the input text ends in the generated text
            input_end = generated_text.find("Response:")
            if input_end != -1:
                response = generated_text[input_end + len("Response:"):].strip()
            else:
                # Fallback: try to find JSON start
                json_start = generated_text.find('{')
                if json_start != -1:
                    response = generated_text[json_start:].strip()
                else:
                    response = generated_text[len(input_text):].strip()

            # Try to parse JSON with post-processing
            try:
                # First try direct parsing
                parsed_response = json.loads(response)
            except json.JSONDecodeError:
                # If that fails, try post-processing
                parsed_response = extract_correct_json(response)
                if parsed_response is None:
                    parsed_response = {"error": "Invalid JSON", "raw_response": response}

            # Store result
            result = {
                "example_id": i + 1,
                "question": example['input'],
                "ground_truth": example['output'],
                "model_response": response,
                "parsed_response": parsed_response,
                "inference_time": inference_time,
                "model_name": model_name
            }

            results.append(result)

        except Exception as e:
            print(f"\n❌ Error on example {i+1}: {e}")
            # Add error result instead of breaking
            result = {
                "example_id": i + 1,
                "question": example['input'],
                "ground_truth": example['output'],
                "model_response": f"ERROR: {e}",
                "parsed_response": {"error": str(e)},
                "inference_time": 0,
                "model_name": model_name
            }
            results.append(result)
            continue

    print(f"\nCompleted inference with {model_name}")
    return results

# %%
def calculate_metrics(results: List[Dict]):
    """Calculate evaluation metrics."""
    total_examples = len(results)
    valid_json_count = 0
    total_inference_time = 0

    # Count valid JSON responses
    for result in results:
        if "error" not in result['parsed_response']:
            valid_json_count += 1
        total_inference_time += result['inference_time']

    metrics = {
        "total_examples": total_examples,
        "valid_json_rate": valid_json_count / total_examples,
        "average_inference_time": total_inference_time / total_examples,
        "total_inference_time": total_inference_time
    }

    return metrics

def compare_entity_extraction(ground_truth: Dict, prediction: Dict):
    """Compare entity extraction accuracy."""
    if "error" in prediction:
        return {
            "dimensions_accuracy": 0.0,
            "measures_accuracy": 0.0,
            "calculations_accuracy": 0.0,
            "filters_accuracy": 0.0,
            "time_references_accuracy": 0.0,
            "overall_accuracy": 0.0
        }

    categories = ['dimensions', 'measures', 'calculations', 'filters', 'time_references']
    accuracies = {}

    for category in categories:
        gt_entities = set(ground_truth.get(category, []))
        pred_entities = set(prediction.get(category, []))

        if len(gt_entities) == 0 and len(pred_entities) == 0:
            accuracies[f"{category}_accuracy"] = 1.0
        elif len(gt_entities) == 0:
            accuracies[f"{category}_accuracy"] = 0.0
        else:
            # Calculate F1-like score
            intersection = len(gt_entities.intersection(pred_entities))
            precision = intersection / len(pred_entities) if len(pred_entities) > 0 else 0
            recall = intersection / len(gt_entities) if len(gt_entities) > 0 else 0
            f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
            accuracies[f"{category}_accuracy"] = f1

    # Overall accuracy (average of all categories)
    accuracies["overall_accuracy"] = sum(accuracies.values()) / len(accuracies)

    return accuracies

# %%
def process_results(all_results: Dict[str, List[Dict]]):
    """Process and analyze all results."""
    print("\nProcessing results...")

    # Check if we have any results
    if not all_results:
        print("❌ No results to process - all models failed!")
        return {}, []

    # Calculate metrics for each model
    metrics = {}
    detailed_results = []

    for model_name, results in all_results.items():
        if not results:
            print(f"⚠️ No results for {model_name}")
            continue

        # Basic metrics
        metrics[model_name] = calculate_metrics(results)

        # Detailed entity extraction analysis
        for result in results:
            entity_accuracy = compare_entity_extraction(
                result['ground_truth'],
                result['parsed_response']
            )

            detailed_result = {
                "example_id": result['example_id'],
                "model_name": model_name,
                "question": result['question'],
                "ground_truth": result['ground_truth'],
                "model_response": result['model_response'],
                "inference_time": result['inference_time'],
                **entity_accuracy
            }

            detailed_results.append(detailed_result)

    return metrics, detailed_results

def create_summary_report(metrics: Dict, detailed_results: List[Dict]):
    """Create a summary report."""
    print("\n" + "="*60)
    print("EVALUATION SUMMARY")
    print("="*60)

    for model_name, model_metrics in metrics.items():
        print(f"\n{model_name}:")
        print(f"  Total Examples: {model_metrics['total_examples']}")
        print(f"  Valid JSON Rate: {model_metrics['valid_json_rate']:.2%}")
        print(f"  Average Inference Time: {model_metrics['average_inference_time']:.3f}s")
        print(f"  Total Inference Time: {model_metrics['total_inference_time']:.2f}s")

    # Calculate average entity extraction accuracy
    if detailed_results:
        df = pd.DataFrame(detailed_results)
        print(f"\nEntity Extraction Accuracy:")
        for model_name in metrics.keys():
            model_df = df[df['model_name'] == model_name]
            if len(model_df) > 0:
                avg_overall = model_df['overall_accuracy'].mean()
                print(f"  {model_name}: {avg_overall:.2%}")
            else:
                print(f"  {model_name}: No results")
    else:
        print(f"\nEntity Extraction Accuracy: No detailed results available")

# %%
def save_to_huggingface(metrics: Dict, detailed_results: List[Dict], repo_name: str = None):
    """Save results to HuggingFace Hub."""
    print("\nSaving results to HuggingFace Hub...")

    # Use provided repo_name or create new one
    if repo_name is None:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        repo_name = f"ssuki/entity-recognition-evaluation-{timestamp}"

    # Prepare results
    results_data = {
        "evaluation_date": datetime.now().isoformat(),
        "test_data_path": TEST_DATA_PATH,
        "metrics": metrics,
        "detailed_results": detailed_results
    }

    # Save locally first
    results_file = f"evaluation_results_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
    with open(results_file, 'w', encoding='utf-8') as f:
        json.dump(results_data, f, indent=2, ensure_ascii=False)

    print(f"Results saved locally: {results_file}")

    # Create CSV for easy analysis
    df = pd.DataFrame(detailed_results)
    csv_file = f"evaluation_results_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    df.to_csv(csv_file, index=False)
    print(f"CSV saved: {csv_file}")

    # Try to upload to HuggingFace
    try:
        api = HfApi()

        # Upload files to the existing repository
        api.upload_file(
            path_or_fileobj=results_file,
            path_in_repo="evaluation_results.json",
            repo_id=repo_name,
            repo_type="dataset"
        )

        api.upload_file(
            path_or_fileobj=csv_file,
            path_in_repo="evaluation_results.csv",
            repo_id=repo_name,
            repo_type="dataset"
        )

        print(f"Results uploaded to: https://huggingface.co/datasets/{repo_name}")

    except Exception as e:
        print(f"Warning: Could not upload to HuggingFace: {e}")
        print("Results saved locally only")

    return results_file, csv_file

# %%
# Debug cell - add this as a new cell
def debug_what_model_generates():
    """See exactly what the model is generating for 2 examples."""

    # Load test data first
    test_data = load_test_data()

    # Load model and tokenizer
    model_config = MODEL_CONFIGS["trained"]
    model, tokenizer = load_model_and_tokenizer(model_config)

    # Test with 2 examples
    for i in range(2):
        test_example = test_data[i]
        prompt_template = load_prompt_template()
        input_text = prompt_template.format(question=test_example['input'])

        print(f"\n{'='*50}")
        print(f"EXAMPLE {i+1}")
        print(f"{'='*50}")

        print("=== INPUT TEXT ===")
        print(repr(input_text))  # Shows exact characters including newlines
        print(f"Length: {len(input_text)}")

        # Tokenize and generate
        inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=1024)
        device = next(model.parameters()).device
        inputs = {k: v.to(device) for k, v in inputs.items()}

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=256,
                temperature=0.1,
                do_sample=False,  # Make it deterministic
                pad_token_id=tokenizer.eos_token_id,
                eos_token_id=tokenizer.eos_token_id,
                use_cache=True,
                num_beams=1
            )

        # Decode full text
        generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

        print("\n=== FULL GENERATED TEXT ===")
        print(repr(generated_text))  # Shows exact characters
        print(f"Length: {len(generated_text)}")

        # Show what we're extracting
        response = generated_text[len(input_text):].strip()
        print("\n=== EXTRACTED RESPONSE ===")
        print(repr(response))  # Shows exact characters

        # Try to parse
        try:
            parsed = json.loads(response)
            print("✅ JSON parsing successful!")
        except json.JSONDecodeError as e:
            print(f"❌ JSON parsing failed: {e}")

    # Clean up
    del model, tokenizer
    torch.cuda.empty_cache()

# Run debug
debug_what_model_generates()
# Out:
# Loaded 100 test examples
# Loading Trained Qwen 1.5B...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/937 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/73.9M [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Loaded adapter from ssuki/qwen-1.5b-entity-recognition
#
# ==================================================
# EXAMPLE 1
# ==================================================
# === INPUT TEXT ===
# '# Entity Recognition for Business Intelligence Questions\n\nYou are an AI assistant specialized in analyzing natural language questions about business intelligence data and extracting structured information.\n\n## Your Task\nGiven a BI question, identify and extract the following entities:\n- **Dimensions**: Attributes or categories used for grouping/filtering (e.g., "publisher", "age", "state", "name", "creation year")\n- **Measures**: Numeric values or metrics (e.g., "revenue", "users", "heads", "count")\n- **Calculations**: Aggregation functions (e.g., "average", "sum", "maximum", "minimum", "count", "total")\n- **Filters**: Conditions or constraints (e.g., "older than 56", "between 10 and 15", "outside California state")\n- **Time References**: Time-related terms (e.g., "last year", "this month", "2023", "creation year")\n\n## Instructions\n1. Read the question carefully\n2. Identify all relevant entities in each category\n3. Use exact terms from the question when possible\n4. Include variations and synonyms (e.g., "publisher" and "publishers")\n5. For filters, capture the complete filter condition (e.g., "older than 56", "between 10 and 15")\n6. Return a JSON object with the extracted entities\n\n## Examples\n\n**Question**: "How many heads of the publishers are older than 56?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers", "age", "older than 56"],\n  "measures": ["heads"],\n  "calculations": ["count"],\n  "filters": ["older than 56"],\n  "time_references": []\n}\n```\n\n**Question**: "What is the average number of users of the publishers whose rank is between 10 and 15?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers"],\n  "measures": ["users"],\n  "calculations": ["average"],\n  "filters": ["between 10 and 15"],\n  "time_references": []\n}\n```\n\n## Output Format\n```json\n{\n  "dimensions": ["list", "of", "dimensions"],\n  "measures": ["list", "of", "measures"],\n  "calculations": ["list", "of", "calculations"],\n  "filters": ["list", "of", "filters"],\n  "time_references": ["list", "of", "time_references"]\n}\n```\n\n## Question: What are the dates that have an average sea level pressure between 30.3 and 31?\n\n## Response:'
# Length: 2156
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# === FULL GENERATED TEXT ===
# '# Entity Recognition for Business Intelligence Questions\n\nYou are an AI assistant specialized in analyzing natural language questions about business intelligence data and extracting structured information.\n\n## Your Task\nGiven a BI question, identify and extract the following entities:\n- **Dimensions**: Attributes or categories used for grouping/filtering (e.g., "publisher", "age", "state", "name", "creation year")\n- **Measures**: Numeric values or metrics (e.g., "revenue", "users", "heads", "count")\n- **Calculations**: Aggregation functions (e.g., "average", "sum", "maximum", "minimum", "count", "total")\n- **Filters**: Conditions or constraints (e.g., "older than 56", "between 10 and 15", "outside California state")\n- **Time References**: Time-related terms (e.g., "last year", "this month", "2023", "creation year")\n\n## Instructions\n1. Read the question carefully\n2. Identify all relevant entities in each category\n3. Use exact terms from the question when possible\n4. Include variations and synonyms (e.g., "publisher" and "publishers")\n5. For filters, capture the complete filter condition (e.g., "older than 56", "between 10 and 15")\n6. Return a JSON object with the extracted entities\n\n## Examples\n\n**Question**: "How many heads of the publishers are older than 56?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers", "age", "older than 56"],\n  "measures": ["heads"],\n  "calculations": ["count"],\n  "filters": ["older than 56"],\n  "time_references": []\n}\n```\n\n**Question**: "What is the average number of users of the publishers whose rank is between 10 and 15?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers"],\n  "measures": ["users"],\n  "calculations": ["average"],\n  "filters": ["between 10 and 15"],\n  "time_references": []\n}\n```\n\n## Output Format\n```json\n{\n  "dimensions": ["list", "of", "dimensions"],\n  "measures": ["list", "of", "measures"],\n  "calculations": ["list", "of", "calculations"],\n  "filters": ["list", "of", "filters"],\n  "time_references": ["list", "of", "time_references"]\n}\n```\n\n## Question: What are the dates that have an average sea level pressure between 30.3 and 31?\n\n## Response: ```json\n[\n    {\n        "dimensions": [\n            "date"\n        ],\n        "measures": [\n            "sea_level_pressure",\n            "average"\n        ],\n        "calculations": [\n            "average"\n        ],\n        "filters": [\n            "between 30.3 and 31"\n        ]\n    }\n]\n``` To solve this problem, we need to analyze the given question and determine the appropriate dimensions, measures, calculations, filters, and time references based on the provided examples. Here\'s how we can break it down:\n\n### Step-by-Step Analysis\n\n1. **Identify Dimensions**:\n   - The question mentions "dates". Therefore, "date" should be included as a dimension.\n   \n2. **Identify Measures**:\r\n   - The question asks about "average sea level pressure". Hence, "sea_level_pressure" and "average" should be considered as measures.\n\n3. **Identify Calculations**:\r\n   - The calculation mentioned is "average".\n\n4. **Identify Filters**:\r\n   - The range specified is "between 30.3 and 31". This indicates a filter condition.\n\n5. **Identify Time References**:\r\n   - No specific time reference is mentioned in the question'
# Length: 3269
#
# === EXTRACTED RESPONSE ===
# '```json\n[\n    {\n        "dimensions": [\n            "date"\n        ],\n        "measures": [\n            "sea_level_pressure",\n            "average"\n        ],\n        "calculations": [\n            "average"\n        ],\n        "filters": [\n            "between 30.3 and 31"\n        ]\n    }\n]\n``` To solve this problem, we need to analyze the given question and determine the appropriate dimensions, measures, calculations, filters, and time references based on the provided examples. Here\'s how we can break it down:\n\n### Step-by-Step Analysis\n\n1. **Identify Dimensions**:\n   - The question mentions "dates". Therefore, "date" should be included as a dimension.\n   \n2. **Identify Measures**:\r\n   - The question asks about "average sea level pressure". Hence, "sea_level_pressure" and "average" should be considered as measures.\n\n3. **Identify Calculations**:\r\n   - The calculation mentioned is "average".\n\n4. **Identify Filters**:\r\n   - The range specified is "between 30.3 and 31". This indicates a filter condition.\n\n5. **Identify Time References**:\r\n   - No specific time reference is mentioned in the question'
# ❌ JSON parsing failed: Expecting value: line 1 column 1 (char 0)
#
# ==================================================
# EXAMPLE 2
# ==================================================
# === INPUT TEXT ===
# '# Entity Recognition for Business Intelligence Questions\n\nYou are an AI assistant specialized in analyzing natural language questions about business intelligence data and extracting structured information.\n\n## Your Task\nGiven a BI question, identify and extract the following entities:\n- **Dimensions**: Attributes or categories used for grouping/filtering (e.g., "publisher", "age", "state", "name", "creation year")\n- **Measures**: Numeric values or metrics (e.g., "revenue", "users", "heads", "count")\n- **Calculations**: Aggregation functions (e.g., "average", "sum", "maximum", "minimum", "count", "total")\n- **Filters**: Conditions or constraints (e.g., "older than 56", "between 10 and 15", "outside California state")\n- **Time References**: Time-related terms (e.g., "last year", "this month", "2023", "creation year")\n\n## Instructions\n1. Read the question carefully\n2. Identify all relevant entities in each category\n3. Use exact terms from the question when possible\n4. Include variations and synonyms (e.g., "publisher" and "publishers")\n5. For filters, capture the complete filter condition (e.g., "older than 56", "between 10 and 15")\n6. Return a JSON object with the extracted entities\n\n## Examples\n\n**Question**: "How many heads of the publishers are older than 56?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers", "age", "older than 56"],\n  "measures": ["heads"],\n  "calculations": ["count"],\n  "filters": ["older than 56"],\n  "time_references": []\n}\n```\n\n**Question**: "What is the average number of users of the publishers whose rank is between 10 and 15?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers"],\n  "measures": ["users"],\n  "calculations": ["average"],\n  "filters": ["between 10 and 15"],\n  "time_references": []\n}\n```\n\n## Output Format\n```json\n{\n  "dimensions": ["list", "of", "dimensions"],\n  "measures": ["list", "of", "measures"],\n  "calculations": ["list", "of", "calculations"],\n  "filters": ["list", "of", "filters"],\n  "time_references": ["list", "of", "time_references"]\n}\n```\n\n## Question: Find the day in which the difference between the max temperature and min temperature was the smallest. Also report the difference.\n\n## Response:'
# Length: 2207
#
# === FULL GENERATED TEXT ===
# '# Entity Recognition for Business Intelligence Questions\n\nYou are an AI assistant specialized in analyzing natural language questions about business intelligence data and extracting structured information.\n\n## Your Task\nGiven a BI question, identify and extract the following entities:\n- **Dimensions**: Attributes or categories used for grouping/filtering (e.g., "publisher", "age", "state", "name", "creation year")\n- **Measures**: Numeric values or metrics (e.g., "revenue", "users", "heads", "count")\n- **Calculations**: Aggregation functions (e.g., "average", "sum", "maximum", "minimum", "count", "total")\n- **Filters**: Conditions or constraints (e.g., "older than 56", "between 10 and 15", "outside California state")\n- **Time References**: Time-related terms (e.g., "last year", "this month", "2023", "creation year")\n\n## Instructions\n1. Read the question carefully\n2. Identify all relevant entities in each category\n3. Use exact terms from the question when possible\n4. Include variations and synonyms (e.g., "publisher" and "publishers")\n5. For filters, capture the complete filter condition (e.g., "older than 56", "between 10 and 15")\n6. Return a JSON object with the extracted entities\n\n## Examples\n\n**Question**: "How many heads of the publishers are older than 56?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers", "age", "older than 56"],\n  "measures": ["heads"],\n  "calculations": ["count"],\n  "filters": ["older than 56"],\n  "time_references": []\n}\n```\n\n**Question**: "What is the average number of users of the publishers whose rank is between 10 and 15?"\n**Output**:\n```json\n{\n  "dimensions": ["publisher", "publishers"],\n  "measures": ["users"],\n  "calculations": ["average"],\n  "filters": ["between 10 and 15"],\n  "time_references": []\n}\n```\n\n## Output Format\n```json\n{\n  "dimensions": ["list", "of", "dimensions"],\n  "measures": ["list", "of", "measures"],\n  "calculations": ["list", "of", "calculations"],\n  "filters": ["list", "of", "filters"],\n  "time_references": ["list", "of", "time_references"]\n}\n```\n\n## Question: Find the day in which the difference between the max temperature and min temperature was the smallest. Also report the difference.\n\n## Response: ```json\n[\n    {\n        "dimension": [\n            "day"\n        ]\n    },\n    {\n        "measure": [\n            "difference",\n            "between",\n            "max",\n            "temperature",\n            "and",\n            "min",\n            "temperature"\n        ],\n        "calculated": [\n            "smallest"\n        ]\n    }\n]\n``` To solve this problem, we need to identify the dimensions, measures, calculations, filters, and time references from the given question. Here\'s how we can break it down:\n\n### Dimensions\nThe question mentions two main groups that could be considered as dimensions: "day" and "date". However, since "day" is more specific and directly related to the date, we will consider it as one dimension.\n\n### Measures\nThe measure mentioned is "difference".\n\n### Calculations\nThe calculation mentioned is "smallest".\n\n### Filters\nThere are no explicit filters provided in the question. We will assume there are no additional filters needed based on the context.\n\n### Time References\nThe question does not mention any specific time reference like "today", "yesterday", etc. So, we will also assume there are no time references needed.\n\nNow let\'s construct the final response using these identified elements:\n\n```json\n{\n'
# Length: 3453
#
# === EXTRACTED RESPONSE ===
# '```json\n[\n    {\n        "dimension": [\n            "day"\n        ]\n    },\n    {\n        "measure": [\n            "difference",\n            "between",\n            "max",\n            "temperature",\n            "and",\n            "min",\n            "temperature"\n        ],\n        "calculated": [\n            "smallest"\n        ]\n    }\n]\n``` To solve this problem, we need to identify the dimensions, measures, calculations, filters, and time references from the given question. Here\'s how we can break it down:\n\n### Dimensions\nThe question mentions two main groups that could be considered as dimensions: "day" and "date". However, since "day" is more specific and directly related to the date, we will consider it as one dimension.\n\n### Measures\nThe measure mentioned is "difference".\n\n### Calculations\nThe calculation mentioned is "smallest".\n\n### Filters\nThere are no explicit filters provided in the question. We will assume there are no additional filters needed based on the context.\n\n### Time References\nThe question does not mention any specific time reference like "today", "yesterday", etc. So, we will also assume there are no time references needed.\n\nNow let\'s construct the final response using these identified elements:\n\n```json\n{'
# ❌ JSON parsing failed: Expecting value: line 1 column 1 (char 0)

# %%
# Main evaluation pipeline
print("Entity Recognition Model Evaluation")
print("=" * 50)

# Create HuggingFace dataset repository
from huggingface_hub import create_repo, HfApi

api = HfApi()

# Create dataset repository
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
repo_name = f"ssuki/entity-recognition-evaluation-examples200-300"

try:
    create_repo(
        repo_id=repo_name,
        repo_type="dataset",
        private=False,
        exist_ok=True
    )
    print(f"✅ Created dataset repository: {repo_name}")
except Exception as e:
    print(f"⚠️ Could not create repository: {e}")
    repo_name = None  # Will create new one in save function

# Check HuggingFace login
try:
    from huggingface_hub import whoami
    username = whoami()
    print(f"Logged in to HuggingFace as: {username}")
except Exception:
    print("Warning: Not logged in to HuggingFace Hub")
    print("Results will be saved locally only")

# Load test data
test_data = load_test_data()

# Run evaluation for each model
all_results = {}

for model_key, model_config in MODEL_CONFIGS.items():
    try:
        # Load model
        model, tokenizer = load_model_and_tokenizer(model_config)

        # Run inference
        results = run_inference(model, tokenizer, test_data, model_config['name'])
        all_results[model_key] = results

        # Clean up
        del model, tokenizer
        torch.cuda.empty_cache()

    except Exception as e:
        print(f"Error evaluating {model_config['name']}: {e}")
        continue

# Process results
metrics, detailed_results = process_results(all_results)

# Create summary
create_summary_report(metrics, detailed_results)

# Save results (pass the repo_name)
results_file, csv_file = save_to_huggingface(metrics, detailed_results, repo_name)

print(f"\nEvaluation completed!")
print(f"Results saved: {results_file}, {csv_file}")
# Out:
# Entity Recognition Model Evaluation
# ==================================================
# ✅ Created dataset repository: ssuki/entity-recognition-evaluation-examples200-300
# Logged in to HuggingFace as: {'type': 'user', 'id': '686e2f4c8cc9f98517dc3543', 'name': 'ssuki', 'fullname': 'Sukruthi Santosh', 'isPro': False, 'avatarUrl': '/avatars/7b5fc575d5e1611a60c25dbf95870267.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'bi-intent-token', 'role': 'fineGrained', 'createdAt': '2025-08-17T18:11:53.275Z', 'fineGrained': {'canReadGatedRepos': True, 'global': [], 'scoped': [{'entity': {'_id': '686e2f4c8cc9f98517dc3543', 'type': 'user', 'name': 'ssuki'}, 'permissions': ['repo.content.read', 'repo.write']}]}}}}
# Loaded 100 test examples
# Loading Trained Qwen 1.5B...
# Loaded adapter from ssuki/qwen-1.5b-entity-recognition
#
# Running inference with Trained Qwen 1.5B...
# Starting inference on 100 examples...
# Processing example 1/100
# Input text length: 2156
# Tokenized input shape: torch.Size([1, 565])
# Inputs moved to device: cuda:0
# Starting generation...
# Generation completed!
# Processing example 2/100
# Input text length: 2207
# Tokenized input shape: torch.Size([1, 566])
# Inputs moved to device: cuda:0
# Starting generation...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1235472395.py in <cell line: 0>()
#      45
#      46         # Run inference
# ---> 47         results = run_inference(model, tokenizer, test_data, model_config['name'])
#      48         all_results[model_key] = results
#      49
#
# /tmp/ipython-input-3218522467.py in run_inference(model, tokenizer, test_data, model_name)
#      32
#      33             with torch.no_grad():
# ---> 34                 outputs = model.generate(
#      35                     **inputs,
#      36                     max_new_tokens=256,
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in generate(self, *args, **kwargs)
#    1971                 with self._enable_peft_forward_hooks(*args, **kwargs):
#    1972                     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1973                     outputs = self.base_model.generate(*args, **kwargs)
#    1974             else:
#    1975                 outputs = self.base_model.generate(**kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2615
#    2616             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2617             result = self._sample(
#    2618                 input_ids,
#    2619                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3599                 is_prefill = False
#    3600             else:
# -> 3601                 outputs = model_forward(**model_inputs, return_dict=True)
#    3602
#    3603             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     957         if return_dict_passed is not None:
#     958             return_dict = return_dict_passed
# --> 959         output = func(self, *args, **kwargs)
#     960         if not return_dict and not isinstance(output, tuple):
#     961             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     448         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     449         ```"""
# --> 450         outputs: BaseModelOutputWithPast = self.model(
#     451             input_ids=input_ids,
#     452             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1081                         monkey_patched_layers.append((module, original_forward))
#    1082
# -> 1083         outputs = func(self, *args, **kwargs)
#    1084         # Restore original forward methods
#    1085         for module, original_forward in monkey_patched_layers:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     377
#     378         for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 379             hidden_states = decoder_layer(
#     380                 hidden_states,
#     381                 attention_mask=causal_mask_mapping[decoder_layer.attention_type],
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, use_cache, cache_position, position_embeddings, **kwargs)
#     229         hidden_states = self.input_layernorm(hidden_states)
#     230         # Self Attention
# --> 231         hidden_states, _ = self.self_attn(
#     232             hidden_states=hidden_states,
#     233             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_value, cache_position, **kwargs)
#     151         query_states = self.q_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     152         key_states = self.k_proj(hidden_states).view(hidden_shape).transpose(1, 2)
# --> 153         value_states = self.v_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     154
#     155         cos, sin = position_embeddings
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/peft/tuners/lora/bnb.py in forward(self, x, *args, **kwargs)
#     478                 result = self.base_layer(x, *args, **kwargs)
#     479             else:
# --> 480                 result = self.base_layer(x, *args, **kwargs)
#     481                 # As per Tim Dettmers, for 4bit, we need to defensively clone here.
#     482                 # The reason is that in some cases, an error can occur that backprop
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/nn/modules.py in forward(self, x)
#     563         weight = self.weight.t() if self.weight.dim() == 2 else self.weight
#     564
# --> 565         return bnb.matmul_4bit(x, weight, bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
#     566
#     567
#
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/autograd/_functions.py in matmul_4bit(A, B, quant_state, out, bias)
#     464             return out
#     465     else:
# --> 466         return MatMul4Bit.apply(A, B, out, bias, quant_state)
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     574             # See NOTE: [functorch vjp and autograd interaction]
#     575             args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 576             return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577
#     578         if not is_setup_ctx_defined:
#
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/autograd/_functions.py in forward(ctx, A, B, out, bias, quant_state)
#     378         # 1. Dequantize
#     379         # 2. MatmulnN
# --> 380         output = torch.nn.functional.linear(A, F.dequantize_4bit(B, quant_state).to(A.dtype).t(), bias)
#     381
#     382         # 3. Save state
#
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/functional.py in dequantize_4bit(A, quant_state, absmax, out, blocksize, quant_type)
#    1001         )
#    1002     else:
# -> 1003         out = torch.ops.bitsandbytes.dequantize_4bit.default(
#    1004             A,
#    1005             absmax,
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     827     # that are named "self". This way, all the aten ops can be called by kwargs.
#     828     def __call__(self, /, *args: _P.args, **kwargs: _P.kwargs) -> _T:
# --> 829         return self._op(*args, **kwargs)
#     830
#     831     # Use positional-only argument to avoid naming collision with aten ops arguments
#
# /usr/local/lib/python3.12/dist-packages/torch/_compile.py in inner(*args, **kwargs)
#      39     if fn is not None:
#      40
# ---> 41         @functools.wraps(fn)
#      42         def inner(*args: _P.args, **kwargs: _P.kwargs) -> _T:
#      43             # cache this on the first invocation to avoid adding too much overhead.
#
# KeyboardInterrupt:
